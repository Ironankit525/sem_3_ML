# %%
import pandas as pd
import numpy as np

# %%
restaurant_data={
    "Table_number":[1,2,3,4,5],
    "Bill_amount":[100,200,150,300,250],
    "Waiter_name":["John","Alice","Bob","Eve","Charlie"],
}

# %%
df=pd.DataFrame(restaurant_data)
print(df)
# Out:
#    Table_number  Bill_amount Waiter_name
# 0             1          100        John
# 1             2          200       Alice
# 2             3          150         Bob
# 3             4          300         Eve
# 4             5          250     Charlie

# %%
print(df["Waiter_name"])
print(df["Bill_amount"])
# Out:
# 0       John
# 1      Alice
# 2        Bob
# 3        Eve
# 4    Charlie
# Name: Waiter_name, dtype: object
# 0    100
# 1    200
# 2    150
# 3    300
# 4    250
# Name: Bill_amount, dtype: int64

# %%
total_bill=[600,5246,2345,24,5243,4533,5342,45,2]
s=pd.Series("total_bill")
print(s)
# Out:
# 0    total_bill
# dtype: object

# %%
print(df.values)
# Out:
# [[1 100 'John']
#  [2 200 'Alice']
#  [3 150 'Bob']
#  [4 300 'Eve']
#  [5 250 'Charlie']]

# %%
stocks={
    "brand":["nike","tata","oneoone","google"],
    "price":[1000,10000,1100000,1000000],
    "in_stock":["true","true","true","false"]
}

sd=pd.DataFrame(stocks)
print(sd)
# Out:
#      brand    price in_stock
# 0     nike     1000     true
# 1     tata    10000     true
# 2  oneoone  1100000     true
# 3   google  1000000    false

# %%
df=pd.read_csv("/Users/ankit/BOX 1/B1 ROOM 1/AI&ML/class5/tips.csv")
print(df)
print(df.tail())
print(df.sum())
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# ...

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 228       13.28  2.72    Male     No   Sat  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print(df.applymap)
# Out:
# <bound method DataFrame.applymap of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
print(df.flags)
print(df.tip)
print(df.agg)
# Out:
# <Flags(allows_duplicate_labels=True)>
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64
# <bound method DataFrame.aggregate of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# ...

# %%
x=df['day']
print(x.shape)

y=df[['day']]
print(y.shape)
# Out:
# (244,)
# (244, 1)

# %%
print(df['day'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 244 entries, 0 to 243
# Series name: day
# Non-Null Count  Dtype
# --------------  -----
# 244 non-null    object
# dtypes: object(1)
# memory usage: 2.0+ KB
# None

# %%
print(df['day'])
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
gg=pd.read_csv("/Users/ankit/BOX 1/B1 ROOM 1/AI&ML/Class6/test.csv")
print(gg)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
gg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
gg.shape
# Out:
# (418, 11)

# %%
gg.sample()
# Out:
#     PassengerId  Pclass             Name   Sex   Age  SibSp  Parch  Ticket  \
# 56          948       3  Cor, Mr. Bartol  male  35.0      0      0  349230
#
#       Fare Cabin Embarked
# 56  7.8958   NaN        S

# %%
gg.head(9)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# ...

# %%
marks=np.array([[45,24,56,23,67],
                [78,56,85,85,46],
                [47,97,98,68,56],
                [36,87,56,87,67],
                [56,76,56,75,46]])

print(marks)
# Out:
# [[45 24 56 23 67]
#  [78 56 85 85 46]
#  [47 97 98 68 56]
#  [36 87 56 87 67]
#  [56 76 56 75 46]]

# %%
gg.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
gg[["Age"]]
# Out:
#       Age
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# ..    ...
# 413   NaN
# 414  39.0
# 415  38.5
# 416   NaN
# 417   NaN
#
# [418 rows x 1 columns]

# %%
gg.iloc[1:4,[1,2,3]]
# Out:
#    Pclass                              Name     Sex
# 1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2       2         Myles, Mr. Thomas Francis    male
# 3       3                  Wirz, Mr. Albert    male

# %%
gg.loc[1:4,"Name":"Cabin"]
# Out:
#                                            Name     Sex   Age  SibSp  Parch  \
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin
# 1   363272   7.0000   NaN
# 2   240276   9.6875   NaN
# 3   315154   8.6625   NaN
# 4  3101298  12.2875   NaN

# %%
gg.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
gg[gg["Age"]>65][["Name","Pclass","Fare"]]
# Out:
#                                                  Name  Pclass      Fare
# 81                                 Straus, Mr. Isidor       1  221.7792
# 96  Cavendish, Mrs. Tyrell William (Julia Florence...       1   78.8500

# %%
gg[(gg["Age"]<10 )| (gg["Age"]>70)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 21           913       3                          Olsen, Master. Artur Karl
# 80           972       3                               Boulos, Master. Akar
# 89           981       2                        Wells, Master. Ralph Lester
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 117         1009       3                    Sandstrom, Miss. Beatrice Irene
# 161         1053       3                     Touma, Master. Georges Youssef
# 194         1086       2                      Drew, Master. Marshall Brines
# 196         1088       1                    Spedden, Master. Robert Douglas
# 201         1093       3            Danbom, Master. Gilbert Sigvard Emanuel
# 203         1095       2                         Quick, Miss. Winifred Vera
# 250         1142       2                              West, Miss. Barbara J
# ...
